# %% [markdown]
# ## Introduction to Machine Learning - 2021/2022 - Unsupervised Learning
# *Student:* João Miguel Antunes Marques
#
# *Number:* 101617

# %% [markdown]
# #### 1

# %%
import generator as g
import random
import util


print("Dataset")
random.seed(1000)
c, x, y, label_1x, label_1y, label_2x, label_2y = g.gen_cases(True)
print("Red:Label 1")
print("Green:Label 2")
util.symbol_plot_dev_2(label_1x, label_1y, label_2x, label_2y)
print("End Dataset")
# Out:
# Dataset
# Red:Label 1
# Green:Label 2
# End Dataset

# %%
import generator as g
import random
import util
import distribution as d

random.seed(1000)
c, x, y, label_1x, label_1y, label_2x, label_2y = g.gen_cases(False)
r1 = random.randint(0, len(x) - 1)
r2 = random.randint(0, len(x) - 1)
r1_value = (x[r1], y[r1])
r2_value = (x[r2], y[r2])
print("a)")
print("Initial:r1 and r2")
print(r1_value)
print(r2_value)
dist = d.Distribution()
r1_values_data, r2_values_data = dist.process_1_a(x, y, r1_value, r2_value)
r1_x, r1_y = util.convert_tuple(r1_values_data)
r2_x, r2_y = util.convert_tuple(r2_values_data)
util.symbol_plot_dev_3(label_1x, label_1y, label_2x, label_2y, r1_x, r1_y, r2_x, r2_y)
print("Final: r1 and r2")
print((r1_x[len(r1_x) - 1], r1_y[len(r1_x) - 1]))
print((r2_x[len(r2_x) - 1], r2_y[len(r2_x) - 1]))

print("b)")
dist = d.Distribution()
print("Initial: r1 and r2")
print(r1_value)
print(r2_value)
r1_values_data, r2_values_data = dist.process_1_b(x, y, r1_value, r2_value)
r1_x, r1_y = util.convert_tuple(r1_values_data)
r2_x, r2_y = util.convert_tuple(r2_values_data)
util.symbol_plot_dev_3(label_1x, label_1y, label_2x, label_2y, r1_x, r1_y, r2_x, r2_y)
print("Final: r1 and r2")
print((r1_x[len(r1_x) - 1], r1_y[len(r1_x) - 1]))
print((r2_x[len(r2_x) - 1], r2_y[len(r2_x) - 1]))
# Out:
# a)
# Initial:r1 and r2
# (3.6481536802862893, 3.681210915881055)
# (2.757893068178816, 0.617398555599665)
# Final: r1 and r2
# (3.6284457325353516, 3.6666414773760434)
# (2.4720558638571872, 0.45294909881411893)
# b)
# Initial: r1 and r2
# (3.6481536802862893, 3.681210915881055)
# (2.757893068178816, 0.617398555599665)
# Final: r1 and r2
# (3.6284457325353516, 3.6666414773760434)
# (2.4720558638571872, 0.45294909881411893)

# %% [markdown]
# Não existe uma diferença nítida da experiência a) para b). Contudo, posso concluir que os pontos r1 e r2 tendem para os valores dos limites usados para definir o dataset [3,3], [-3,-3].
# Basicamente se o valor for superior a 3 este decresce, se for inferior a -3 este cresce.

# %% [markdown]
# #### 2
# Para melhor comparar, vou repetir a experiência 1 e alterar o alpha para poder obter alterações mais significativas.
# ##### a)

# %%
import generator as g
import random
import util
import distribution as d

random.seed(1000)
c, x, y, label_1x, label_1y, label_2x, label_2y = g.gen_cases(False)
r1 = random.randint(0, len(x) - 1)
r2 = random.randint(0, len(x) - 1)
r1_value = (x[r1], y[r1])
r2_value = (x[r2], y[r2])
print("Initial: r1 and r2")
print(r1_value)
print(r2_value)
print("1 a)")
dist = d.Distribution(alpha=0.0001)
r1_values_data, r2_values_data = dist.process_1_a(x, y, r1_value, r2_value)
r1_x, r1_y = util.convert_tuple(r1_values_data)
r2_x, r2_y = util.convert_tuple(r2_values_data)
util.symbol_plot_dev_3(label_1x, label_1y, label_2x, label_2y, r1_x, r1_y, r2_x, r2_y)
print("Final: r1 and r2")
print((r1_x[len(r1_x) - 1], r1_y[len(r1_x) - 1]))
print((r2_x[len(r2_x) - 1], r2_y[len(r2_x) - 1]))

print("1 b)")
print("Initial: r1 and r2")
print(r1_value)
print(r2_value)
r1_values_data, r2_values_data = dist.process_1_b(x, y, r1_value, r2_value)
r1_x, r1_y = util.convert_tuple(r1_values_data)
r2_x, r2_y = util.convert_tuple(r2_values_data)
util.symbol_plot_dev_3(label_1x, label_1y, label_2x, label_2y, r1_x, r1_y, r2_x, r2_y)
print("Final: r1 and r2")
print((r1_x[len(r1_x) - 1], r1_y[len(r1_x) - 1]))
print((r2_x[len(r2_x) - 1], r2_y[len(r2_x) - 1]))


print("2 a)")
print("Initial: r1 and r2")
print(r1_value)
print(r2_value)
r1_values_data, r2_values_data = dist.process_2_a(x, y, r1_value, r2_value)
r1_x, r1_y = util.convert_tuple(r1_values_data)
r2_x, r2_y = util.convert_tuple(r2_values_data)
util.symbol_plot_dev_3(label_1x, label_1y, label_2x, label_2y, r1_x, r1_y, r2_x, r2_y)
print("Final: r1 and r2")
print((r1_x[len(r1_x) - 1], r1_y[len(r1_x) - 1]))
print((r2_x[len(r2_x) - 1], r2_y[len(r2_x) - 1]))
# Out:
# r1 and r2
# (4.174818405351376, 3.2496388972535133)
# (-1.6697860280119492, -3.2645106204841237)
# 1 a)
# Final: r1 and r2
# (4.116619606600128, 3.2381164321484106)
# (-1.7383059432577712, -3.2542620857125293)
# 1 b)
# Initial: r1 and r2
# (4.174818405351376, 3.2496388972535133)
# (-1.6697860280119492, -3.2645106204841237)
# Final: r1 and r2
# (4.116619606600128, 3.2381164321484106)
# (-1.7383059432577712, -3.2542620857125293)
# 2 a)
# Initial: r1 and r2
# (4.174818405351376, 3.2496388972535133)
# (-1.6697860280119492, -3.2645106204841237)
# Final: r1 and r2
# (3.665386221954557, 2.7401589880550357)
# (-2.1701847597584907, -3.7649668761202553)

# %% [markdown]
# Nitidamente que a experiência 2) a) tem um realojamento do r1 e r2 muito mais acentuado que na experiência anterior.

# %% [markdown]
# ##### b)

# %%
import generator as g
import random
import util
import distribution as d
import matplotlib.pyplot as plt

random.seed(1000)
c, x, y, label_1x, label_1y, label_2x, label_2y = g.gen_cases(False)
r1 = random.randint(0, len(x) - 1)
r2 = random.randint(0, len(x) - 1)
r1_value = (x[r1], y[r1])
r2_value = (x[r2], y[r2])
print("2 b)")
print("Initial: r1 and r2")
print(r1_value)
print(r2_value)
dist = d.Distribution(alpha=0.0001)
r1_values_data, r2_values_data = dist.process_2_a(x, y, r1_value, r2_value)
r1_x, r1_y = util.convert_tuple(r1_values_data)
r2_x, r2_y = util.convert_tuple(r2_values_data)
print("Final: r1 and r2")
r1_t = (r1_x[len(r1_x) - 1], r1_y[len(r1_x) - 1])
r2_t = (r2_x[len(r2_x) - 1], r2_y[len(r2_x) - 1])
print(r1_t)
print(r2_t)
color_1_x, color_1_y = util.convert_tuple(util.closer_list(r1_t, r2_t, label_1x, label_1y))
color_2_x, color_2_y = util.convert_tuple(util.closer_list(r1_t, r2_t, label_2x, label_2y))
color_3_x, color_3_y = util.convert_tuple(util.closer_list(r1_t, r2_t, label_1x, label_1y, False))
color_4_x, color_4_y = util.convert_tuple(util.closer_list(r1_t, r2_t, label_2x, label_2y, False))
plt.plot(
    color_1_x, color_1_y, 'rx',
    color_2_x, color_2_y, 'gx',
    color_3_x, color_3_y, 'yx',
    color_4_x, color_4_y, 'bx',
    [r1_t[0]], [r1_t[1]], '+',
    [r2_t[0]], [r2_t[1]], '+')
plt.axis('equal')
plt.show()
# Out:
# 2 b)
# Initial: r1 and r2
# (-3.0925514703608274, -3.803931811736248)
# (-4.3989796533609, -3.8236632508107684)
# Final: r1 and r2
# (0.4440282135259558, -0.26713803755091825)
# (-2.639936332962614, -2.064620099305256)

# %% [markdown]
# ##### c)

# %%
import generator as g
import random
import util
import distribution as d
import matplotlib.pyplot as plt

random.seed(1000)
c, x, y, label_1x, label_1y, label_2x, label_2y = g.gen_cases(False)
r1 = random.randint(0, len(x) - 1)
r2 = random.randint(0, len(x) - 1)
r1_value = (x[r1], y[r1])
r2_value = (x[r2], y[r2])
print("2 c)")
for i in range(3):
    print("Initial: r1 and r2")
    print(r1_value)
    print(r2_value)
    dist = d.Distribution(alpha=0.0001)
    r1_values_data, r2_values_data = dist.process_2_a(x, y, r1_value, r2_value)
    r1_x, r1_y = util.convert_tuple(r1_values_data)
    r2_x, r2_y = util.convert_tuple(r2_values_data)
    print("Final: r1 and r2")
    r1_t = (r1_x[len(r1_x) - 1], r1_y[len(r1_x) - 1])
    r2_t = (r2_x[len(r2_x) - 1], r2_y[len(r2_x) - 1])
    print(r1_t)
    print(r2_t)
    color_1_x, color_1_y = util.convert_tuple(util.closer_list(r1_t, r2_t, label_1x, label_1y))
    color_2_x, color_2_y = util.convert_tuple(util.closer_list(r1_t, r2_t, label_2x, label_2y))
    color_3_x, color_3_y = util.convert_tuple(util.closer_list(r1_t, r2_t, label_1x, label_1y, False))
    color_4_x, color_4_y = util.convert_tuple(util.closer_list(r1_t, r2_t, label_2x, label_2y, False))
    plt.plot(
        color_1_x, color_1_y, 'rx',
        color_2_x, color_2_y, 'gx',
        color_3_x, color_3_y, 'yx',
        color_4_x, color_4_y, 'bx',
        [r1_t[0]], [r1_t[1]], '+',
        [r2_t[0]], [r2_t[1]], '+')
    plt.axis('equal')
    plt.show()
    r1_value = r1_t
    r2_value = r2_t
# Out:
# 2 c)
# Initial: r1 and r2
# (4.374516407712347, 2.4097704463558225)
# (-3.1102461469171803, -0.4626981414963982)
# Final: r1 and r2
# (3.7585030647773574, 1.7937050318137147)
# (-3.7257024049882, -1.0781347304318025)
# Initial: r1 and r2
# (3.7585030647773574, 1.7937050318137147)
# (-3.7257024049882, -1.0781347304318025)
# Final: r1 and r2
# (3.601261457790412, 1.636429712536)
# (-3.8808874700138754, -1.2332818335015523)
# Initial: r1 and r2
# (3.601261457790412, 1.636429712536)
# (-3.8808874700138754, -1.2332818335015523)
# Final: r1 and r2
# (3.5643677816218773, 1.5995072533877974)
# (-3.9172727884639906, -1.2696243985539324)

# %% [markdown]
# Resumidamente, consigo ver 3 cores distintas, em que se nota a label 1 e label 2. No meio sobressai uma terceira cor, em que são os pontos que estão perto de uma das labels mas nao o suficientemente perto para pertencerem aquele grupo.
# No c) foram criados gráficos a cada 10 iterações, em que se nota o r1 e r2 a ajustar.

# %% [markdown]
# #### 3

# %%
import random

import agglomerative as ag
import generator as g

random.seed(1000)
c, x, y, label_1x, label_1y, label_2x, label_2y = g.gen_cases(True, 200)
data_set = [(x[i], y[i]) for i in range(len(x))]
node = ag.agglomerative(data_set)
node.print_tree()
# Out:
# (-2.5282008532981006, -6.656062417458146)
#
# (-1.9028591217642368, -5.946568435940632)
#
# (-2.460839422270328, -5.798149793656357)
#
# (-2.3058781700021846, -5.779174583105174)
#
# (-2.1606386824909194, -5.541639389373983)
#
# (-2.2244743456847926, -5.216428688976632)
#
# (-3.0218001885156727, -5.5615418032723625)
#
# (-2.700479986830199, -5.624246703325295)
#
# (-2.648160405153608, -5.454190566770371)
#
# (-2.6231782302532034, -5.396906570995014)
#
# (-2.613159796889185, -5.3779603142478045)
#
# (-2.8746184876861554, -6.072335853065644)
#
# (-3.2072115960412066, -6.209656775148602)
#
# (-1.0010593890733173, -6.522566253914615)
#
# (-0.8134814865118041, -8.104097323819353)
#
# (-1.5728767988051704, -7.757866266016638)
#
# (-1.1316063638908451, -7.640702388696271)
#
# (-5.618999350187219, -6.636879007372837)
#
# (-5.352547792632797, -5.3554627156624255)
#
# (-5.248815166065166, -5.8507504629349825)
#
# (-4.297797714366198, -5.2300883241236775)
#
# (-4.266108861562376, -4.980390808036765)
#
# (-4.286101427813062, -4.86566351184679)
#
# (-4.108724195084971, -5.852667089221069)
#
# (-3.7238355722247327, -5.279261838192939)
#
# (-3.5874058866171485, -5.684405726153093)
#
# (-3.834192933285805, -5.649842069537518)
#
# (-3.7889118195563505, -5.825566210230551)
#
# (-4.4201522584612265, -6.593758445920856)
#
# (-4.899221360922652, -6.452156775623754)
#
# (-4.560662509199212, -6.239667062936166)
#
# (-4.680096703907451, -6.2567505746327186)
#
# (-3.9503475175086047, -7.162415256164776)
#
# (-3.435321545727083, -6.54277678569459)
#
# (-3.376134541158258, -6.925984294254017)
#
# (-4.702938888492487, -8.538553844675532)
#
# (-3.2943818561163987, -9.041784028230804)
#
# (-3.2078637634210323, -7.536762158274462)
#
# (-2.8206626461951436, -8.002970045071159)
#
# (5.941035230781344, 1.277007570163847)
#
# (4.392804869556111, 1.5479991771091424)
#
# (4.692083593002869, 1.504277877403603)
#
# (4.299897935915999, 0.8628971496631266)
#
# (4.5670565276219675, 1.1291737332048808)
#
# (3.2573555948565707, 0.46879455059149855)
#
# (3.4313186300643417, -0.05662022834907532)
#
# (3.445685354201829, 1.8223397487365127)
#
# (3.4057126986143333, 2.014580185790289)
#
# (3.3441824694839384, 2.082107416835098)
#
# (3.6125386487913254, 2.175870433967203)
#
# (3.6491013039062157, 2.096419219569779)
#
# (3.4188446013809752, 2.2006945914097122)
#
# (3.535422407526, 2.235634466030147)
#
# (3.0377132309700783, 1.72222625098217)
#
# (3.1697163475335337, 1.7517570880039777)
#
# (2.9986910026440734, 1.8951609330031463)
#
# (3.129728940023455, 1.962178386863293)
#
# (3.096944346335444, 2.1762925838041336)
#
# (3.245894967231819, 2.259992279849417)
#
# (3.1558303636429277, 2.3492856527369455)
#
# (3.1620470428691254, 2.36403516405647)
#
# (2.918781492261017, 2.0719024651548885)
#
# (2.928249802087787, 2.271782211814435)
#
# (2.825842680050005, 2.2252416472047205)
#
# (2.7859544259833386, 2.266010794137484)
#
# (2.7777113441209895, 2.227352011831017)
#
# (3.74592844140377, 1.4505479872789753)
#
# (3.751049708370541, 1.6608458148016603)
#
# (3.275131513826633, 1.4712540735067396)
#
# (3.085772357370218, 1.1646375063320669)
#
# (3.0573515109850296, 1.2303650611524786)
#
# (2.7189606031547986, 0.9088302890735642)
#
# (2.65140715970579, 1.7892891802298605)
#
# (2.4428884016367673, 1.7003232142608065)
#
# (2.3861886667667718, 1.8179301849343268)
#
# (2.3069763183523238, 1.401661984156338)
#
# (2.0714318963287983, 1.2120304243047761)
#
# (1.8796686711016837, 1.3134228539767663)
#
# (1.6604330407869605, 1.5441527964981325)
#
# (1.6382396027481945, 2.012601354404773)
#
# (2.0189947455187167, 1.704932523165266)
#
# (2.170863676717386, 1.7420536197189722)
#
# (2.115398735177494, 1.814062866148125)
#
# (2.0170493250492987, 2.024855793452192)
#
# (1.9089305116436197, 1.9094196135617438)
#
# (1.9218162344147478, 0.562476132621248)
#
# (1.3329950645615625, 0.6817482507772059)
#
# (0.871669582579722, 1.6350888857741128)
#
# (0.23305654364248163, 2.7714512175675643)
#
# (0.7637201970165703, 2.736309103164328)
#
# (0.939907154791757, 3.005667621983694)
#
# (0.9965994462240495, 3.0129885430550223)
#
# (1.5288095451028092, 5.257038172269974)
#
# (2.0950213065551493, 5.330715467349174)
#
# (1.778643593628047, 5.577116022456069)
#
# (1.1852749131029325, 4.368999293263231)
#
# (1.9814675238571262, 4.613828224912662)
#
# (1.7813354661651304, 4.050480061226439)
#
# (1.9498910889651864, 4.085183637601547)
#
# (1.64603772672491, 4.242482642074309)
#
# (1.6098501589354812, 4.215537007671702)
#
# (1.5522312699574534, 4.112795969856892)
#
# (1.4112824472983545, 4.1273200055524555)
#
# (1.4647002813148333, 4.101176357837424)
#
# (1.803335980259374, 3.409145181671394)
#
# (1.8864632074314467, 3.3785590032447974)
#
# (1.7750982371246296, 3.231886702244523)
#
# (1.611810278966871, 3.2151132706067203)
#
# (1.3109678384152255, 3.09131732246143)
#
# (1.3725908950012613, 3.402912456888919)
#
# (1.4577452933793054, 3.3188895825499607)
#
# (1.4133786232817036, 3.241713212198477)
#
# (2.3184359030273303, 3.0182364254683747)
#
# (1.8669174646737592, 2.876917834846941)
#
# (1.6727304183638985, 2.47661554642305)
#
# (1.5562168714574043, 2.4590836792297868)
#
# (2.0353012390719845, 2.461907444049355)
#
# (2.040698517421498, 2.528111302717245)
#
# (2.26293029809126, 2.260902475839443)
#
# (2.3503703833469185, 2.283790582903733)
#
# (2.3157886163355466, 2.280063920889564)
#
# (3.0498706328706793, 3.899652857140691)
#
# (3.323371287311559, 3.9837949176705334)
#
# (3.1999536328809812, 3.9279185589107666)
#
# (3.1795327277352925, 3.4981499268680203)
#
# (2.9428075218437924, 3.571903979972996)
#
# (2.9331897205740702, 3.6865954981655653)
#
# (2.915527754298844, 3.773679569885601)
#
# (2.565594212956923, 3.6783299512484326)
#
# (2.524035142515403, 3.6365585495291795)
#
# (2.4793919165316987, 3.4150352373283996)
#
# (2.352351247721015, 3.5134856828644154)
#
# (2.2150420852904675, 3.5953596981117424)
#
# (2.340042698664535, 3.669127175811878)
#
# (2.6752601187428744, 4.210690064659518)
#
# (2.618815608837585, 4.088031583548202)
#
# (2.5841765037304483, 4.150364115357577)
#
# (2.194461180572726, 4.174286643271713)
#
# (2.291919331576695, 4.215716391637811)
#
# (2.1284068946203707, 3.7474477083856153)
#
# (2.1262858155296005, 3.769232456185043)
#
# (2.1605108311552064, 3.9534185605644976)
#
# (2.1761841374341997, 3.9967576608885085)
#
# (3.485824241544788, 3.129093744225952)
#
# (3.396449275415166, 3.4144002566775518)
#
# (3.4538815617509853, 3.3681695985770417)
#
# (3.436051217024505, 3.3863018225545485)
#
# (3.39310108796946, 3.239635443926688)
#
# (3.3328523307297058, 3.309284791290522)
#
# (3.2969556274580976, 3.2929088715876)
#
# (3.1503191049215347, 3.0920928456118175)
#
# (3.248307587205008, 2.8896738589298367)
#
# (3.264603511281388, 2.936497267020284)
#
# (3.453737803112172, 2.942615416749525)
#
# (3.3463175602362503, 3.0065293334804943)
#
# (3.359756315228257, 2.75847408204836)
#
# (3.3903770763050787, 2.6474621790414297)
#
# (3.7189935346195053, 2.6192624528898167)
#
# (3.5820273086000967, 2.551001338792921)
#
# (3.898458771977137, 2.5849300749505044)
#
# (3.7670259084049618, 2.8020393868456646)
#
# (3.9050598503603453, 2.7911628576594154)
#
# (2.747676564471406, 2.9722319201432454)
#
# (2.59907078109162, 2.980310522765269)
#
# (2.772045344168283, 3.248346472697741)
#
# (2.595459295230204, 3.2245620616608233)
#
# (2.903863325797167, 3.012728858329633)
#
# (3.0161636894327617, 2.9498035471280826)
#
# (2.9476155633189944, 2.902562486850343)
#
# (2.9159315025083865, 3.288540403300691)
#
# (3.047925681480362, 3.2440352530347534)
#
# (3.010725006924901, 3.1803617038958607)
#
# (2.9381040263890643, 2.538139535062708)
#
# (2.6637239953498537, 2.6261657589266814)
#
# (2.82386309557504, 2.6359285246885675)
#
# (2.7750857396414683, 2.7993079371557723)
#
# (2.8064071907710764, 2.7624055192681016)
#
# (2.4943626247969064, 2.6121456399284737)
#
# (2.6815687619713295, 2.461136834388126)
#
# (2.668238751432887, 2.3022743991008983)
#
# (2.5679337292083764, 2.2972019508810653)
#
# (4.3200176153413095, 3.545735064860665)
#
# (4.395519303664195, 3.3620620756642356)
#
# (4.281485441922223, 3.337340334621953)
#
# (3.6727073766231806, 3.0320114436140626)
#
# (3.7681177012644906, 3.2245098928705747)
#
# (3.8619546888503637, 3.139475464104343)
#
# (3.7838016736795783, 3.090412241101798)
#
# (3.984533897277455, 3.2668282703156564)
#
# (4.100320992565232, 3.0524905292573545)
#
# (4.006091805081475, 3.0637836450939977)
#
# (3.608370228984191, 3.38804769883348)
#
# (3.643387422985654, 3.4059055053436653)
#
# (3.68173948075779, 3.547235930421898)
#
# (3.738748162697135, 3.4705846054761786)
#
# (4.0323146245588175, 3.6897675402971855)
#
# (3.8390985444996106, 3.929500505411755)
#
# (3.85330914033847, 3.8192468653762432)
#
# (3.631136524547953, 3.6637260931713653)
#
# (3.7311384897176842, 3.7728635109273054)
#
# (4.668644423919768, 2.2243157125772473)
#
# (4.536863379931007, 2.0569707053451087)
#
# (4.335161326447935, 1.9889439187726548)
#
# (4.743139393311229, 2.873003421506078)
#
# (4.5898760692614236, 2.8740741473146283)
#
# (4.612611383434828, 2.765089691056899)
#
# (4.271174689593914, 2.756332497888166)
#
# (4.329085512769211, 2.73264124476986)
#
# (4.089854604831168, 2.6270942993786797)
#
# (4.218795101496307, 2.486700652142047)
#
# (4.189180839211641, 2.4723651978694505)
#
# (5.408665441419821, 2.460935348079756)
#
# (5.857015953531313, 2.4330447204676116)
#
# (5.440307582333332, 3.3142303232169597)
#
# (5.022765714272138, 3.657734967467084)
#
# (4.849535476845192, 3.4331720625016318)
#
# (5.000582545766372, 3.2569362897142065)
#
# (3.083482461062373, 5.142284891834799)
#
# (2.805012116157232, 4.799515168661308)
#
# (2.4834692409464383, 4.573309719756483)
#
# (2.739199930469537, 4.509368048875714)
#
# (3.392611955989495, 4.532062174586097)
#
# (3.04571126676224, 4.5347128558170855)
#
# (3.0654238187529863, 4.269316982793187)
#
# (2.89254684458608, 4.220771990972568)
#
# (2.997728118242345, 4.134134844315128)
#
# (3.8739141265304946, 4.759721894102342)
#
# (3.996935003797377, 4.160148961435292)
#
# (3.539840899535305, 4.097188597904285)
#
# (3.572626008677307, 4.095747092842771)
#
# (3.500638917846039, 3.9909524836246413)
#
# (3.527354065877223, 3.887062635135604)
#
# (4.727621662328834, 5.945216575622583)
#
# (4.434721886900992, 5.640909233240393)
#
# (4.550936854714287, 5.014286779915997)
#
# (4.937360247089953, 4.566068806865317)
#
# (4.709851545466441, 4.106250637361137)
#
# (4.884082337901488, 4.003505972285393)
#
# (4.893349248332413, 4.0688673200427665)
#
# (-2.1078753860699004, 2.586173788434383)
#
# (-3.7991329568861345, 2.8734407951958936)
#
# (-3.6004790702906635, 3.2898588250165304)
#
# (-3.6701183389250396, 1.707735501265029)
#
# (-3.136762407084586, 2.2929304276905906)
#
# (-4.946343162013603, 0.32887752370348844)
#
# (-4.638591789898802, 0.1984593484353856)
#
# (-6.04585526623431, -0.9004965109711636)
#
# (-5.268577261789899, -0.6810274029622891)
#
# (-4.857008367970806, -1.120532839434467)
#
# (-5.097624779312317, -1.221046999189632)
#
# (-6.985518879000481, -3.971428988775263)
#
# (-6.393625214047157, -2.307398154886097)
#
# (-6.867265610282599, -1.6631216052660016)
#
# (-5.044912252596703, -2.945989173947737)
#
# (-5.368505185085216, -3.784095603063912)
#
# (-5.870594622391757, -3.192368296659926)
#
# (-4.993200797329596, -2.133110126916942)
#
# (-5.1193320212412985, -1.9543101876928555)
#
# (-3.955526685414866, -2.9288226299809472)
#
# (-3.7269138795032086, -2.624204234931919)
#
# (-3.9167723166516923, -2.121007357897642)
#
# (-4.120491470001106, -2.208575405992984)
#
# (-4.248570630653312, -2.19751134978463)
#
# (-4.560951201125585, -2.332308833802215)
#
# (-4.305919661866265, -2.743768968293028)
#
# (-4.291580936052185, -2.5344832669053763)
#
# (0.1923646346540635, -0.9616754690724796)
#
# (0.14162451756491778, -1.6789497795443105)
#
# (-0.26254264961625307, -1.7786723829918278)
#
# (-0.4633756087665688, -1.2961855543794938)
#
# (-0.8153489477484177, -1.5376771031809333)
#
# (-1.1281685492938032, -1.525403092395977)
#
# (-2.2727673255381697, 1.1152614247487653)
#
# (-1.823251445285835, 0.29842912906042773)
#
# (-1.1965384819273923, 0.7922937609329228)
#
# (-1.5779216174466486, -0.7842459151465699)
#
# (-2.2790875444395717, -0.3110864107674911)
#
# (-1.949313807495018, -0.4697319018075765)
#
# (-0.26168384002418144, -0.575748932805519)
#
# (-0.66212870893259, -0.6224125639635494)
#
# (-0.8397042916368909, -0.6088900645951276)
#
# (-0.7278345077608028, 0.16354692361850942)
#
# (-1.42832850798618, -0.16112462868785737)
#
# (-1.0969227446444478, -0.1929116417365413)
#
# (-3.117272173079841, 0.21069762131683323)
#
# (-3.443221829324611, 0.38055898692565826)
#
# (-2.76242453106505, -0.021196841822828993)
#
# (-2.7563335623736154, -0.30289228844483373)
#
# (-2.8874121743371446, -0.17198004631042618)
#
# (-3.0536509774849634, -0.1635692482192903)
#
# (-3.3477799716532957, -0.2652612268095451)
#
# (-3.045816917866749, -0.33738951391082983)
#
# (-3.082026413391474, -0.4747039713623882)
#
# (-3.257822518500011, -1.1418220120011189)
#
# (-3.166401947331654, -1.030939577208024)
#
# (-2.643381375087623, -1.2178137323480853)
#
# (-2.8106993329075203, -1.402596643735177)
#
# (-2.850554878499924, -1.211935676956123)
#
# (-2.921445188294009, -3.7857324729352615)
#
# (-2.7700380843995935, -3.7211330665515456)
#
# (-2.680998411319666, -2.765582673556606)
#
# (-2.466491974387572, -3.1144213244100394)
#
# (-2.560510232142174, -2.983450367754779)
#
# (-2.6652157730768127, -2.9983816946974375)
#
# (-2.4155072173120313, -2.6930662127906326)
#
# (-2.3313107925124883, -2.9614595276054483)
#
# (-2.284568202136359, -2.8240338920803825)
#
# (-3.2264453769188473, -2.8855343175667048)
#
# (-3.229599246744189, -2.795389407994601)
#
# (-3.094817764616549, -2.506886186538059)
#
# (-3.251569576497551, -2.453410370380244)
#
# (-3.3386185365707943, -2.538669516359202)
#
# (-3.1071321773270664, -4.59284957999579)
#
# (-3.1878387220961524, -4.648746199015757)
#
# (-3.0128805238607606, -5.0118750007650075)
#
# (-3.245413689992058, -5.132198019289371)
#
# (-2.1670680246013667, -4.776543811080284)
#
# (-2.1911896036283895, -4.94661525425697)
#
# (-2.3554735392582202, -4.950922807937037)
#
# (-2.5914790468963886, -4.281716072480747)
#
# (-2.845275411621445, -4.4996065076528025)
#
# (-2.6583975049379105, -4.70783967055428)
#
# (-3.520595216638502, -3.726232448476525)
#
# (-3.5434406880409064, -3.849608075439858)
#
# (-3.627848333640059, -4.6573585802269815)
#
# (-3.849422387347568, -4.249677294699652)
#
# (-4.580990194662966, -3.4198820678242066)
#
# (-4.426730218384231, -3.5570802981628598)
#
# (-4.417277526105482, -3.730478512288699)
#
# (-4.171480983789038, -3.2994427947990914)
#
# (-4.1420718963700995, -3.577914238417722)
#
# (-4.459784933021258, -4.023281509832842)
#
# (-4.370235696999103, -3.8947827271395923)
#
# (-4.641230305419553, -4.441027133387208)
#
# (-4.713042901880236, -4.258032894927078)

# %% [markdown]
# #### 4
# Como no video nao mencionava o número mínimo de pontos, considerei 2 para fazer um cluster.
# Os pontos com + significam que ficaram sem grupo. Cada grupo tem cor ou forma diferente.

# %%
import generator as g
import random
import clustering as clu
import util
import const
import matplotlib.pyplot as plt

random.seed(1000)
c, x, y, label_1x, label_1y, label_2x, label_2y = g.gen_cases(True)
data_set = [(x[i], y[i]) for i in range(len(x))]
va = clu.Cluster(0.5)
va.fit(data_set)
vx, vy = util.convert_tuple(va.without_cluster)
plt.plot(vx, vy, '+')
for i in range(len(va.cluster)):
    vx, vy = util.convert_tuple(va.cluster[i])
    plt.plot(vx, vy, const.COLORS[i])
plt.axis('equal')
plt.show()
print(va.cluster)
print(len(va.cluster))
# Out:
# [[(3.480276568073092, 3.151996719896184), (3.1979388335671857, 3.119801681948492), (3.1163483124702727, 2.6864862467652917), (2.6849847189403686, 2.840648946686551), (2.402743978619501, 2.8572114807077025), (2.2163214443382837, 3.273831083587702), (1.928765960491081, 3.4616394893031526), (1.6271177984739955, 3.2499717477982295), (1.2108681085224027, 3.499391137414367), (1.1433218179557965, 3.951125401131663), (1.2659549696544967, 4.081897045061878), (1.5924549612739607, 4.4346065367574194), (1.7737662706987984, 4.208411861393582), (1.9965213890192548, 4.091020947695422), (2.3997102504458634, 3.999621046056317), (2.793503839139279, 3.710611869219079), (2.